# %% [markdown]
# ## Numerical Simulation :
#
# #### 2. Find the probability using Monte Carlo simulation for l < t, for the general case and ﬁnd the value of the π using some special case (e.g. l = 2, and t = 3)
#
#
#
# First, we are going to do the general case

# %% [markdown]
# For the general case, we are going to :
#
# First calculate the probability of crossing vs. not crossing using the formula for L<T $  {\pi}=\frac{2l}{Pt}  $ and generate random variables for l ( length of the needle ) and t ( distance between strips )

# %%
import random
import math 

T = random.randint(1,20)
L = random.uniform(0,T) # to comply with L<T


crossing =(2*L)/(T*math.pi)
not_crossing=1-((2*L)/(T*math.pi))


print("P(crossing l<t)=", crossing)
print("P(not crossing l<t)=",not_crossing)
# Out:
# P(crossing l<t)= 0.20109416717650416
# P(not crossing l<t)= 0.7989058328234958

# %% [markdown]
# Using Montecarlo simulation , create a function *pi_estimate* that will take the lenght of the needle and distance.
# This function will generate 1 angle for each needle and will clasiffy the needle in 2 buckets
#    * Crossing
#    * Not crossing
#
#
# Then the function will count the # of needles crossing and will estimate PI based on the total number of needles that      crossed

# %%
import random
import math 

def pi_estimate(r,n,T,L):
    data = []  
    for sim in range(r): #number of times we run the sim
        cross = 0
        for i in range(n):#number of needles we throw
            center = random.uniform(0, T / 2.0) 
            theta = random.uniform(0, math.pi / 2)
            criteria = center - (L / 2.0) * math.cos(theta)  
            if criteria < 0: # if the difference of distance is < than 0 then is crossing the strip
                cross+= 1
        pi = (2.0 * L * n)/(T * cross)
        prob_cross=cross/n
        data.append([sim,cross,prob_cross,pi])
    return data

# %%
r = 10   # number of times we run the simulation
n = 4000 # number of needles thrown each time 

print("Width of the board : ",T)
print("Lenght of the needle : ", L)
print ('[Runs],[Cross],[Prob_cross] ,[pi]')


pi_estimate(r,n,T,L)
# Out:
# Width of the board :  15
# Lenght of the needle :  4.7381696871109735
# [Runs],[Cross],[Prob_cross] ,[pi]
# [[0, 773, 0.19325, 3.269112332633703],
#  [1, 781, 0.19525, 3.2356259066912325],
#  [2, 800, 0.2, 3.1587797914073157],
#  [3, 833, 0.20825, 3.0336420565736524],
#  [4, 785, 0.19625, 3.219138640924653],
#  [5, 841, 0.21025, 3.0047845816003003],
#  [6, 852, 0.213, 2.965990414466963],
#  [7, 819, 0.20475, 3.0854991857458516],
#  [8, 842, 0.2105, 3.0012159538311787],
#  [9, 823, 0.20575, 3.0705028349038304]]

# %% [markdown]
# Now, we are gonig to run the simulation for special case like l=2 and t=3

# %%
print ('[Runs] [Crossing] [pi] for l=2 and t=3')
pi_estimate(r,n,3,2)
# Out:
# [Runs] [Crossing] [pi] for l=2 and t=3
# [[0, 1693, 0.42325, 3.1502264225241188],
#  [1, 1664, 0.416, 3.2051282051282053],
#  [2, 1728, 0.432, 3.0864197530864197],
#  [3, 1753, 0.43825, 3.0424034987640236],
#  [4, 1675, 0.41875, 3.18407960199005],
#  [5, 1659, 0.41475, 3.2147880249146072],
#  [6, 1691, 0.42275, 3.1539522964715156],
#  [7, 1702, 0.4255, 3.1335683509596555],
#  [8, 1669, 0.41725, 3.195526263231476],
#  [9, 1730, 0.4325, 3.0828516377649327]]

# %% [markdown]
# ===========================================================================================================================
#
# #### 3. Find the probability using Monte Carlo simulation (l > t) for the general case.
# #### From the probability formula we found for l < t, the probability is linear with l/t.

# %% [markdown]
# When the needle is long there is a little bit more complex geometry as, at certain angles, the needle will cross an edge from any position of the midpoint.
#
# The equation below shows the probability for l>t based on the length of the needle and width of the boards.

# %% [markdown]
# $$Pr = \frac{2}{\pi}{\cos^{-1}(\frac{t}{l}}) + \frac{2l}{{\pi}t}(1-\sqrt{(1-(\frac{t}{l})^{2}}))$$
#
# If we define $  {x}=\frac{l}{t}  $ as the ratio of the lenght of the needle to the width of the board and normalize it, we get:
#
#
# $$Pr = \frac{2}{\pi}({x}-\sqrt{x^{2}-1} + {\sec^{-1}x})$$

# %%
import random
import math 
import mpmath
import numpy as np

## If T<L

TT = random.randint(1,20)
LL = random.uniform(T,40) 

print("Width of the board : ",TT)
print("Lenght of the needle : ",LL)


x=LL/TT

crossing =(2/math.pi)*(x-np.sqrt(x**2 -1)+mpmath.asec(x))
not_crossing =1-crossing

print("P(crossing l> t)=", crossing)
print("P(not crossing l> t)=",not_crossing)
# Out:
# Width of the board :  11
# Lenght of the needle :  20.151728733502754
# P(crossing l> t)= 0.821486253160371
# P(not crossing l> t)= 0.178513746839629

# %% [markdown]
# ==============================================================================================================
#
#
#
# Now, we are gonig to write a Montecarlo simulation for long needle. When the needle is longer, the probability of crossing the lines will be higher
#
# Let ${\phi}$ denote the angle between the needle and the parallel line and θ = arcsin(d/l)
#
#
# Then if ${\theta} ≤{\phi}≤ {\pi}-{\theta}$, then the needle intersect aﬃrmatively the parallel lines and the probability of the needle intersecting the parallel lines is 1.
#
#
# If ${0}\leq{\phi}\le {\theta}$  or  ${\pi}−{\theta}\le {\phi}\leq{\pi}$, then the needle would cross the lines ⇐⇒ $\frac{l}{2}{\sin}{\phi} \ge \frac{d}{2}$
#
#
# I am going to create some random variables for those angles and build the function to give me the number of crossing assuming those conditions

# %%
import random
import math 
r = 10   # number of times we run the simulation
n = 4000 # number of needles thrown each time 

def prob_cross_long(r,n,TT,LL):
    data_long = []  
    for sim in range(r): #number of times we run the sim
        cross = 0
        for i in range(n):#number of needles we throw
            center = random.uniform(0, TT / 2.0) 
            theta = random.uniform(0, math.pi / 2)
            phi1=random.uniform(0,theta)
            phi2=random.uniform(math.pi-theta,math.pi)  
            criteria1 = (LL/TT) * math.sin(phi1)  
            criteria2 = (LL/TT) * math.sin(phi2) 
            if criteria1 > 1: # if the difference of distance is > than 1 then is crossing the strip
                cross+= 1
            if criteria2 > 1: # if the difference of distance is > than 1 then is crossing the strip
                cross+= 1
        data_long.append([sim,cross,cross/n])
    return data_long
print ('[Runs] [Crossing] [Prob]')
prob_cross_long(r,n,TT,LL)
# Out:
# [Runs] [Crossing] [Prob]
# [[0, 2079, 0.51975],
#  [1, 2044, 0.511],
#  [2, 2045, 0.51125],
#  [3, 2093, 0.52325],
#  [4, 2129, 0.53225],
#  [5, 2070, 0.5175],
#  [6, 2078, 0.5195],
#  [7, 2063, 0.51575],
#  [8, 2129, 0.53225],
#  [9, 2087, 0.52175]]

# %% [markdown]
# #### 4. After writing your general code in Part 3 plot the Probability vs l/t ratio. *Hint: You need to run the simulations for diﬀerent values of (l/t)*

# %%
import matplotlib.pyplot as plt
import mpmath
import math

xx = np.linspace(1, 10, 1000) #x=l/t ( which is >1 )
prob_long=(2/math.pi)*(xx-np.sqrt((xx)**2 -1)+ mpmath.asec(xx))
plt.plot(xx,prob_long)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-2e782d3a0c36> in <module>
#       5
#       6 xx = np.linspace(1, 10, 1000) #x=l/t ( which is >1 )
# ----> 7 prob_long=(2/math.pi)*(xx-np.sqrt((xx)**2 -1)+ mpmath.asec(xx))
#       8 plt.plot(xx,prob_long)
#       9
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\ctx_mp_python.py in f_wrapped(ctx, *args, **kwargs)
#    1029             def f_wrapped(ctx, *args, **kwargs):
#    1030                 convert = ctx.convert
# -> 1031                 args = [convert(a) for a in args]
#    1032                 prec = ctx.prec
#    1033                 try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\ctx_mp_python.py in <listcomp>(.0)
#    1029             def f_wrapped(ctx, *args, **kwargs):
#    1030                 convert = ctx.convert
# ...
